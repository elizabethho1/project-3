# %%
import pandas as pd

# %%
#load file
cost_of_living_csv = "./Resources/cost-of-living.csv"
cost_of_living_2_csv = "./Resources/cost-of-living_v2.csv"

# %%
#read into pandas dataframes
csv1 = pd.read_csv(cost_of_living_csv)
csv2 = pd.read_csv(cost_of_living_2_csv)

# %%
# Out:
#         city      country  Meal, Inexpensive Restaurant (USD)  \
# 0      Seoul  South Korea                                7.68
# 1   Shanghai        China                                5.69
# 2  Guangzhou        China                                4.13
# 3     Mumbai        India                                3.68
# 4      Delhi        India                                4.91
#
#    Meal for 2 People, Mid-range Restaurant, Three-course (USD)  \
# 0                                              53.78
# 1                                              39.86
# 2                                              28.47
# 3                                              18.42
# 4                                              22.11
#
#    One-way Ticket (Local Transport) (USD)  Monthly Pass (Regular Price) (USD)  \
# 0                                    1.00                               42.25
# 1                                    0.57                               28.47
# ...

# %%
csv1_updated = csv1.rename(columns={'Meal, Inexpensive Restaurant (USD)': 'meal_inexpensive',
                                    
                           })
csv1_updated.head()
# Out:
#    Unnamed: 0      city      country  meal_inexpensive  \
# 0           0     Delhi        India              4.90
# 1           1  Shanghai        China              5.59
# 2           2   Jakarta    Indonesia              2.54
# 3           3    Manila  Philippines              3.54
# 4           4     Seoul  South Korea              7.16
#
#    Meal for 2 People, Mid-range Restaurant, Three-course (USD)  \
# 0                                              22.04
# 1                                              40.51
# 2                                              22.25
# 3                                              27.40
# 4                                              52.77
#
#    One-way Ticket (Local Transport) (USD)  Monthly Pass (Regular Price) (USD)  \
# 0                                    0.49                               11.63
# 1                                    0.56                               27.94
# ...
