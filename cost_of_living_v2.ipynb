# %%
import pandas as pd
import numpy as np
import json

# %%
#load file
cost_of_living_2_csv = "./Resources/cost-of-living_v2.csv"
inflation_csv = "./Resources/inflation.csv"
Worldcities_csv = "./Resources/worldcities.csv"

# %%
#read into pandas dataframes and rename columns
csv2 = pd.read_csv(cost_of_living_2_csv)
worldcities = pd.read_csv(Worldcities_csv)
inflation = pd.read_csv(inflation_csv)
inflation = inflation.rename(columns={'Country': 'country','2021':'2021 inflation rate'})
countries = pd.read_json(r"./Resources/countries.json")
countries = countries.rename(columns={'name': 'country'})
countries
# Out:
#                  timezones                         latlng        country  \
# 0          [America/Aruba]           [12.5, -69.96666666]          Aruba
# 1             [Asia/Kabul]                       [33, 65]    Afghanistan
# 2          [Africa/Luanda]                  [-12.5, 18.5]         Angola
# 3       [America/Anguilla]          [18.25, -63.16666666]       Anguilla
# 4       [Europe/Mariehamn]              [60.116667, 19.9]  Åland Islands
# ..                     ...                            ...            ...
# 242         [Pacific/Apia]  [-13.58333333, -172.33333333]          Samoa
# 243            [Asia/Aden]                       [15, 48]          Yemen
# 244  [Africa/Johannesburg]                      [-29, 24]   South Africa
# 245        [Africa/Lusaka]                      [-15, 30]         Zambia
# 246        [Africa/Harare]                      [-20, 30]       Zimbabwe
#
#     country_code     capital
# 0             AW  Oranjestad
# 1             AF       Kabul
# 2             AO      Luanda
# 3             AI  The Valley
# 4             AX   Mariehamn
# ..           ...         ...
# 242           WS        Apia
# 243           YE      Sana'a
# 244           ZA    Pretoria
# 245           ZM      Lusaka
# 246           ZW      Harare
#
# [247 rows x 5 columns]

# %%
# concatenate city with country 
worldcities['City, Country'] = worldcities[['city','country']].apply(",".join, axis=1)

# %%
csv2 = csv2.rename(columns={'Meal, Inexpensive Restaurant (USD)': 'meal_inexpensive',
                                              'Meal for 2 People, Mid-range Restaurant, Three-course (USD)': 'two_person_meal_midrange',
                                              'One-way Ticket (Local Transport) (USD)': 'one_way_transport_ticket',
                                              'Monthly Pass (Regular Price) (USD)': 'monthly_transport_ticket',
                                              'Gasoline (1 liter) (USD)': 'one_liter_gasoline',
                                              'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment (USD)': 'utilities_915sqft',
                                              'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL) (USD)':'internet',
                                              'Fitness Club, Monthly Fee for 1 Adult (USD)': 'monthly_gym_fee',
                                              'Apartment (1 bedroom) in City Centre (USD)': 'center_city_1_bd',
                                              'Apartment (1 bedroom) Outside of Centre (USD)': 'outside_of_city_1_bd',
                                              'Average Monthly Net Salary (After Tax) (USD)': 'avg_monthly_salary'      
                                    })

csv2['City, Country'] = csv2[['city','country']].apply(",".join, axis=1)
csv2.head()
# Out:
#         city      country  meal_inexpensive  two_person_meal_midrange  \
# 0      Seoul  South Korea              7.68                     53.78
# 1   Shanghai        China              5.69                     39.86
# 2  Guangzhou        China              4.13                     28.47
# 3     Mumbai        India              3.68                     18.42
# 4      Delhi        India              4.91                     22.11
#
#    one_way_transport_ticket  monthly_transport_ticket  one_liter_gasoline  \
# 0                      1.00                     42.25                1.43
# 1                      0.57                     28.47                1.20
# 2                      0.36                     28.47                1.19
# 3                      0.25                      4.91                1.35
# 4                      0.49                     11.67                1.24
#
#    utilities_915sqft  internet  monthly_gym_fee  \
# 0             182.13     22.48            55.88
# 1              66.00     17.07            63.49
# 2              59.65     16.66            34.17
# 3              43.57      9.33            25.37
# 4              58.07      7.95            21.20
#
#    Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child (USD)  \
# 0                                             404.15
# 1                                            1382.62
# 2                                             555.18
# 3                                             107.07
# 4                                              74.00
#
#    International Primary School, Yearly for 1 Child (USD)  center_city_1_bd  \
# 0                                           17902.55                 742.54
# 1                                           26379.45                1091.93
# 2                                           24556.21                 533.28
# 3                                            3682.67                 522.40
# 4                                            1964.24                 229.84
#
#    outside_of_city_1_bd  avg_monthly_salary      City, Country
# 0                557.52             2689.62  Seoul,South Korea
# 1                569.88             1419.87     Shanghai,China
# 2                317.45             1211.68    Guangzhou,China
# 3                294.05              640.81       Mumbai,India
# 4                135.31              586.46        Delhi,India

# %%
# add longitude and latitude for each city
city_merged_df = pd.merge(csv2, worldcities, how='inner',on=['City, Country','City, Country']) 
cities_merged_df= city_merged_df[['city_x', 'country_x', 'meal_inexpensive','two_person_meal_midrange','one_way_transport_ticket','monthly_transport_ticket','one_liter_gasoline','utilities_915sqft','internet','monthly_gym_fee','Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child (USD)','International Primary School, Yearly for 1 Child (USD)','center_city_1_bd','outside_of_city_1_bd','avg_monthly_salary','City, Country','lat','lng','population']].copy()
final_cities_merged_df = cities_merged_df.rename(columns={'city_x': 'city', 'country_x':'country'})

# %%
# before removing nan
final_cities_merged_df.count()
# Out:
# city                                                                         4903
# country                                                                      4903
# meal_inexpensive                                                             4432
# two_person_meal_midrange                                                     4451
# one_way_transport_ticket                                                     3351
# monthly_transport_ticket                                                     2741
# one_liter_gasoline                                                           4244
# utilities_915sqft                                                            4481
# internet                                                                     4610
# monthly_gym_fee                                                              3483
# Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child (USD)    3686
# International Primary School, Yearly for 1 Child (USD)                       3256
# center_city_1_bd                                                             3540
# outside_of_city_1_bd                                                         3469
# avg_monthly_salary                                                           3418
# City, Country                                                                4903
# lat                                                                          4903
# lng                                                                          4903
# population                                                                   4856
# dtype: int64

# %%
# after removing some nan information
final_cities_merged_df = final_cities_merged_df[final_cities_merged_df['utilities_915sqft'].notna()]
final_cities_merged_df.count()
# Out:
# city                                                                         4481
# country                                                                      4481
# meal_inexpensive                                                             4185
# two_person_meal_midrange                                                     4202
# one_way_transport_ticket                                                     3232
# monthly_transport_ticket                                                     2685
# one_liter_gasoline                                                           4094
# utilities_915sqft                                                            4481
# internet                                                                     4432
# monthly_gym_fee                                                              3351
# Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child (USD)    3618
# International Primary School, Yearly for 1 Child (USD)                       3215
# center_city_1_bd                                                             3404
# outside_of_city_1_bd                                                         3337
# avg_monthly_salary                                                           3304
# City, Country                                                                4481
# lat                                                                          4481
# lng                                                                          4481
# population                                                                   4440
# dtype: int64

# %%
#displaying final data for cities
final_cities_merged_df
# Out:
#                     city      country  meal_inexpensive  \
# 0                  Seoul  South Korea              7.68
# 1               Shanghai        China              5.69
# 2              Guangzhou        China              4.13
# 3                 Mumbai        India              3.68
# 4                  Delhi        India              4.91
# ...                  ...          ...               ...
# 4893            Tirupati        India              2.46
# 4894        Port Douglas    Australia             15.97
# 4895         Rockhampton    Australia             14.95
# 4900  Ixtapa Zihuatanejo       Mexico              5.16
# 4901             Iqaluit       Canada             29.65
#
#       two_person_meal_midrange  one_way_transport_ticket  \
# 0                        53.78                      1.00
# 1                        39.86                      0.57
# 2                        28.47                      0.36
# 3                        18.42                      0.25
# 4                        22.11                      0.49
# ...                        ...                       ...
# 4893                      9.21                      0.21
# 4894                     67.28                       NaN
# 4895                     64.56                      2.29
# 4900                     30.94                       NaN
# 4901                     74.27                      6.30
#
#       monthly_transport_ticket  one_liter_gasoline  utilities_915sqft  \
# 0                        42.25                1.43             182.13
# 1                        28.47                1.20              66.00
# 2                        28.47                1.19              59.65
# 3                         4.91                1.35              43.57
# 4                        11.67                1.24              58.07
# ...                        ...                 ...                ...
# 4893                     12.28                1.29              24.93
# 4894                       NaN                1.36             129.12
# 4895                     91.74                1.43             106.86
# 4900                       NaN                1.01              77.35
# 4901                       NaN                 NaN             259.40
#
#       internet  monthly_gym_fee  \
# 0        22.48            55.88
# 1        17.07            63.49
# 2        16.66            34.17
# 3         9.33            25.37
# 4         7.95            21.20
# ...        ...              ...
# 4893     10.75            15.15
# 4894     52.33              NaN
# 4895     42.47            46.21
# 4900     27.46            25.78
# 4901     84.00            71.64
#
#       Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child (USD)  \
# 0                                                404.15
# 1                                               1382.62
# 2                                                555.18
# 3                                                107.07
# 4                                                 74.00
# ...                                                 ...
# 4893                                              36.85
# 4894                                            1359.16
# 4895                                                NaN
# 4900                                                NaN
# 4901                                                NaN
#
#       International Primary School, Yearly for 1 Child (USD)  \
# 0                                              17902.55
# 1                                              26379.45
# 2                                              24556.21
# 3                                               3682.67
# 4                                               1964.24
# ...                                                 ...
# 4893                                            1228.18
# 4894                                            3295.96
# 4895                                           27183.18
# 4900                                                NaN
# 4901                                                NaN
#
#       center_city_1_bd  outside_of_city_1_bd  avg_monthly_salary  \
# 0               742.54                557.52             2689.62
# 1              1091.93                569.88             1419.87
# 2               533.28                317.45             1211.68
# 3               522.40                294.05              640.81
# 4               229.84                135.31              586.46
# ...                ...                   ...                 ...
# 4893             82.90                 61.41              614.09
# 4894               NaN                   NaN             5946.32
# 4895            781.58                594.63             3481.06
# 4900            412.55                257.84                 NaN
# 4901               NaN                   NaN                 NaN
#
#                   City, Country      lat       lng  population
# 0             Seoul,South Korea  37.5600  126.9900  22394000.0
# 1                Shanghai,China  31.1667  121.4667  22118000.0
# 2               Guangzhou,China  23.1288  113.2590  21489000.0
# 3                  Mumbai,India  19.0758   72.8775  22186000.0
# 4                   Delhi,India  28.6667   77.2167  31870000.0
# ...                         ...      ...       ...         ...
# 4893             Tirupati,India  13.6500   79.4167      3165.0
# 4894     Port Douglas,Australia -16.4834  145.4652      3504.0
# 4895      Rockhampton,Australia -23.3750  150.5117      1953.0
# 4900  Ixtapa Zihuatanejo,Mexico  17.6367 -101.5514      8992.0
# 4901             Iqaluit,Canada  63.7598  -68.5107      7740.0
#
# [4481 rows x 19 columns]

# %%
# average the columns from cities dataframe per country - display in new dataframe
world_data_df = final_cities_merged_df[['country', 'meal_inexpensive','two_person_meal_midrange','one_way_transport_ticket','monthly_transport_ticket','one_liter_gasoline','utilities_915sqft','internet','monthly_gym_fee','Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child (USD)','International Primary School, Yearly for 1 Child (USD)','center_city_1_bd','avg_monthly_salary']]
world_data_df = world_data_df .groupby('country').mean()
# adding longitude, latitude, captial and inflation rate for each country
world_merged_df = pd.merge(world_data_df, countries, how='inner',on=['country','country']) 
world_merged2_df = pd.merge(world_merged_df,inflation,how='inner',on=['country','country']) 
world_merged2_df
# Out:
#          country  meal_inexpensive  two_person_meal_midrange  \
# 0    Afghanistan          1.690000                  5.650000
# 1        Albania          4.430000                 25.906667
# 2        Algeria          1.942273                 13.200952
# 3         Angola          7.840000                 64.250000
# 4      Argentina          6.496923                 27.245385
# ..           ...               ...                       ...
# 146   Uzbekistan          3.696667                 19.191667
# 147      Vanuatu         12.710000                 55.060000
# 148      Vietnam          1.956000                 21.424000
# 149       Zambia          3.000000                 18.370000
# 150     Zimbabwe          6.843750                 36.250000
#
#      one_way_transport_ticket  monthly_transport_ticket  one_liter_gasoline  \
# 0                    0.230000                 15.250000            0.890000
# 1                    0.256667                 10.813333            1.760000
# 2                    0.220952                 10.275385            0.294545
# 3                    0.590000                 31.780000            0.330000
# 4                    0.359091                 19.100000            0.877692
# ..                        ...                       ...                 ...
# 146                  0.173333                 10.506000            0.816667
# 147                  1.270000                       NaN            1.440000
# 148                  0.345000                  8.296667            1.014000
# 149                  1.450000                 38.640000            1.360000
# 150                  0.666667                 30.000000            1.437500
#
#      utilities_915sqft    internet  monthly_gym_fee  \
# 0            31.990000  715.630000        13.560000
# 1            91.830000   15.706000        28.847500
# 2            42.192174   39.645000        14.684091
# 3            30.780000  192.230000        40.050000
# 4            53.173077   22.165385        22.597273
# ..                 ...         ...              ...
# 146          45.048333   16.818333        23.471667
# 147         285.200000  141.900000        67.470000
# 148          59.348000   11.264000        27.460000
# 149         140.690000  103.740000        23.820000
# 150          65.502500  102.812500        30.000000
#
#      Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child (USD)  \
# 0                                            25.990000
# 1                                           105.754000
# 2                                            51.689375
# 3                                           929.370000
# 4                                           164.786923
# ..                                                 ...
# 146                                         135.630000
# 147                                         544.080000
# 148                                         266.704000
# 149                                         171.240000
# 150                                         261.292500
#
#      ...   2018    2019    2020 2021 inflation rate Unnamed: 57 Unnamed: 58  \
# 0    ...   0.63    2.30    5.44                5.06         NaN         NaN
# 1    ...   2.03    1.41    1.62                2.04         NaN         NaN
# 2    ...   3.51    1.95    2.42                7.23         NaN         NaN
# 3    ...  19.63   17.08   21.02               23.85         NaN         NaN
# 4    ...  34.28   53.55   42.02               48.41         NaN         NaN
# ..   ...    ...     ...     ...                 ...         ...         ...
# 146  ...  17.68   14.53   12.86               10.69         NaN         NaN
# 147  ...   2.31    2.75    2.92                2.39         NaN         NaN
# 148  ...   3.54    2.80    3.22                1.83         NaN         NaN
# 149  ...   7.49    9.80   15.73               22.02         NaN         NaN
# 150  ...  10.61  255.29  557.21               98.55         NaN         NaN
#
#     Unnamed: 59 Unnamed: 60  Unnamed: 61 Unnamed: 62
# 0           NaN         NaN          NaN         NaN
# 1           NaN         NaN          NaN         NaN
# 2           NaN         NaN          NaN         NaN
# 3           NaN         NaN          NaN         NaN
# 4           NaN         NaN          NaN         NaN
# ..          ...         ...          ...         ...
# 146         NaN         NaN          NaN         NaN
# 147         NaN         NaN          NaN         NaN
# 148         NaN         NaN          NaN         NaN
# 149         NaN         NaN          NaN         NaN
# 150         NaN         NaN          NaN         NaN
#
# [151 rows x 79 columns]

# %%
final_world_merged_df= world_merged2_df [['country', 'meal_inexpensive','two_person_meal_midrange','one_way_transport_ticket','monthly_transport_ticket','one_liter_gasoline','utilities_915sqft','internet','monthly_gym_fee','Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child (USD)','International Primary School, Yearly for 1 Child (USD)','center_city_1_bd','avg_monthly_salary','latlng','capital','2021 inflation rate']]
final_world_merged_df
# Out:
#          country  meal_inexpensive  two_person_meal_midrange  \
# 0    Afghanistan          1.690000                  5.650000
# 1        Albania          4.430000                 25.906667
# 2        Algeria          1.942273                 13.200952
# 3         Angola          7.840000                 64.250000
# 4      Argentina          6.496923                 27.245385
# ..           ...               ...                       ...
# 146   Uzbekistan          3.696667                 19.191667
# 147      Vanuatu         12.710000                 55.060000
# 148      Vietnam          1.956000                 21.424000
# 149       Zambia          3.000000                 18.370000
# 150     Zimbabwe          6.843750                 36.250000
#
#      one_way_transport_ticket  monthly_transport_ticket  one_liter_gasoline  \
# 0                    0.230000                 15.250000            0.890000
# 1                    0.256667                 10.813333            1.760000
# 2                    0.220952                 10.275385            0.294545
# 3                    0.590000                 31.780000            0.330000
# 4                    0.359091                 19.100000            0.877692
# ..                        ...                       ...                 ...
# 146                  0.173333                 10.506000            0.816667
# 147                  1.270000                       NaN            1.440000
# 148                  0.345000                  8.296667            1.014000
# 149                  1.450000                 38.640000            1.360000
# 150                  0.666667                 30.000000            1.437500
#
#      utilities_915sqft    internet  monthly_gym_fee  \
# 0            31.990000  715.630000        13.560000
# 1            91.830000   15.706000        28.847500
# 2            42.192174   39.645000        14.684091
# 3            30.780000  192.230000        40.050000
# 4            53.173077   22.165385        22.597273
# ..                 ...         ...              ...
# 146          45.048333   16.818333        23.471667
# 147         285.200000  141.900000        67.470000
# 148          59.348000   11.264000        27.460000
# 149         140.690000  103.740000        23.820000
# 150          65.502500  102.812500        30.000000
#
#      Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child (USD)  \
# 0                                            25.990000
# 1                                           105.754000
# 2                                            51.689375
# 3                                           929.370000
# 4                                           164.786923
# ..                                                 ...
# 146                                         135.630000
# 147                                         544.080000
# 148                                         266.704000
# 149                                         171.240000
# 150                                         261.292500
#
#      International Primary School, Yearly for 1 Child (USD)  center_city_1_bd  \
# 0                                          1491.530000             108.920000
# 1                                          2139.690000             215.952500
# 2                                          2110.672000             136.258000
# 3                                          2705.620000             220.390000
# 4                                          4008.716364             234.369167
# ..                                                 ...                    ...
# 146                                        3445.440000             205.891667
# 147                                        6158.730000             995.460000
# 148                                       13258.606000             396.828000
# 149                                       14061.390000             262.010000
# 150                                        7087.500000             196.586667
#
#      avg_monthly_salary                       latlng       capital  \
# 0            195.860000                     [33, 65]         Kabul
# 1            352.356000                     [41, 20]        Tirana
# 2            263.939500                      [28, 3]       Algiers
# 3           1428.770000                [-12.5, 18.5]        Luanda
# 4            441.514167                   [-34, -64]  Buenos Aires
# ..                  ...                          ...           ...
# 146          257.381667                     [41, 64]      Tashkent
# 147          677.680000                   [-16, 167]     Port Vila
# 148          406.477500  [16.16666666, 107.83333333]         Hanoi
# 149          396.940000                    [-15, 30]        Lusaka
# 150          311.110000                    [-20, 30]        Harare
#
#      2021 inflation rate
# 0                   5.06
# 1                   2.04
# 2                   7.23
# 3                  23.85
# 4                  48.41
# ..                   ...
# 146                10.69
# 147                 2.39
# 148                 1.83
# 149                22.02
# 150                98.55
#
# [151 rows x 16 columns]
